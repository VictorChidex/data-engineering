# %%
import pandas as pd

# %%
pd.__file__
# Out:
# '/home/chidex/DE/data-engineering/pipeline/.venv/lib/python3.13/site-packages/pandas/__init__.py'

# %%
prefix = 'https://github.com/DataTalksClub/nyc-tlc-data/releases/download/misc/'
url = f'{prefix}/taxi_zone_lookup.csv'

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %%
df.shape
# Out:
# (265, 4)

# %%
len(df)
# Out:
# 1369765

# %%
df.()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1       1.0  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2       1.0  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3       1.0  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4       2.0  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10         1.0                  N           142            43
# 1           0.20         1.0                  N           238           151
# 2          14.70         1.0                  N           132           165
# 3          10.60         1.0                  N           138           132
# 4           4.94         1.0                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
dtype = {
    "LocationID": "int64",
    "Borough": "string",
    "Zone": "string",
    "service_zone": "string"
}

df = pd.read_csv(
    url,
    dtype=dtype
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       1 dtype = {
#       2     "LocationID": "int64",
#       3     "Borough": "string",
#       4     "Zone": "string",
#       5     "service_zone": "string"
#       6 }
# ----> 8 df = pd.read_csv(
#       9     url,
#      10     dtype=dtype
#      11 )
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1         1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2         1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3         1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4         2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           2.10           1                  N           142            43
# 1           0.20           1                  N           238           151
# 2          14.70           1                  N           132           165
# 3          10.60           1                  N           138           132
# 4           4.94           1                  N            68            33
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df['tpep_pickup_datetime']
# Out:
# 0         2021-01-01 00:30:10
# 1         2021-01-01 00:51:20
# 2         2021-01-01 00:43:30
# 3         2021-01-01 00:15:48
# 4         2021-01-01 00:31:49
#                   ...
# 1369760   2021-01-25 08:32:04
# 1369761   2021-01-25 08:34:00
# 1369762   2021-01-25 08:37:00
# 1369763   2021-01-25 08:28:00
# 1369764   2021-01-25 08:38:00
# Name: tpep_pickup_datetime, Length: 1369765, dtype: datetime64[ns]

# %%
df.shape
# Out:
# (1369765, 18)

# %%
import sys
# !uv pip install -v sqlalchemy
# Out:
# DEBUG uv 0.9.21 (0dc9556ad 2025-12-30)
# DEBUG Acquired shared lock for `/home/chidex/.cache/uv`
# DEBUG Searching for default Python interpreter in virtual environments
# DEBUG Found `cpython-3.13.11-linux-x86_64-gnu` at `/home/chidex/DE/data-engineering/pipeline/.venv/bin/python3` (active virtual environment)
# DEBUG Using Python 3.13.11 environment at: .venv
# DEBUG Acquired exclusive lock for `.venv`
# DEBUG Requirement satisfied: greenlet>=1 ; platform_machine == 'AMD64' or platform_machine == 'WIN32' or platform_machine == 'aarch64' or platform_machine == 'amd64' or platform_machine == 'ppc64le' or platform_machine == 'win32' or platform_machine == 'x86_64'
# DEBUG Requirement satisfied: sqlalchemy
# DEBUG Requirement satisfied: typing-extensions>=4.6.0
# Audited 1 package in 27ms
# DEBUG Released lock at `/home/chidex/DE/data-engineering/pipeline/.venv/.lock`
# DEBUG Released lock at `/home/chidex/.cache/uv/.lock`

# %%
# !pwd
# !ls -ld .

#Run this in a terminal (NOT Jupyter):
#sudo chown -R chidex:chidex /home/chidex/DE/data-engineering/pipeline
# Out:
# /home/chidex/DE/data-engineering/pipeline
# drwxr-xr-x 5 chidex chidex 4096 Jan 19 11:54 .

# %%
import sys
# !uv add sqlalchemy
# Out:
# Resolved 120 packages in 0.72ms
# Audited 13 packages in 0.19ms

# %%
# !uv pip install -v notebook
# Out:
# DEBUG uv 0.9.21 (0dc9556ad 2025-12-30)
# DEBUG Acquired shared lock for `/home/chidex/.cache/uv`
# DEBUG Searching for default Python interpreter in virtual environments
# DEBUG Found `cpython-3.13.11-linux-x86_64-gnu` at `/home/chidex/DE/data-engineering/pipeline/.venv/bin/python3` (active virtual environment)
# DEBUG Using Python 3.13.11 environment at: .venv
# DEBUG Acquired exclusive lock for `.venv`
# DEBUG Requirement satisfied: anyio
# DEBUG Requirement satisfied: anyio>=3.1.0
# DEBUG Requirement satisfied: argon2-cffi-bindings
# DEBUG Requirement satisfied: argon2-cffi>=21.1
# DEBUG Requirement satisfied: arrow>=0.15.0
# DEBUG Requirement satisfied: asttokens>=2.1.0
# DEBUG Requirement satisfied: async-lru>=1.0.0
# DEBUG Requirement satisfied: attrs>=22.2.0
# DEBUG Requirement satisfied: babel>=2.10
# DEBUG Requirement satisfied: beautifulsoup4
# DEBUG Requirement satisfied: bleach[css]!=5.0.0
# DEBUG Requirement satisfied: certifi
# ...

# %%
# !uv --version
# Out:
# uv 0.9.21 (0dc9556ad 2025-12-30)

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
# !uv add psycopg2-binary
# Out:
# Resolved 120 packages in 0.69ms
# Audited 13 packages in 0.16ms

# %%
from sqlalchemy import create_engine
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0               1  2021-01-01 00:30:10   2021-01-01 00:36:12                1
# 1               1  2021-01-01 00:51:20   2021-01-01 00:52:19                1
# 2               1  2021-01-01 00:43:30   2021-01-01 01:11:06                1
# 3               1  2021-01-01 00:15:48   2021-01-01 00:31:01                0
# 4               2  2021-01-01 00:31:49   2021-01-01 00:48:21                1
# ...           ...                  ...                   ...              ...
# 1369760      <NA>  2021-01-25 08:32:04   2021-01-25 08:49:32             <NA>
# 1369761      <NA>  2021-01-25 08:34:00   2021-01-25 09:04:00             <NA>
# 1369762      <NA>  2021-01-25 08:37:00   2021-01-25 08:53:00             <NA>
# 1369763      <NA>  2021-01-25 08:28:00   2021-01-25 08:50:00             <NA>
# 1369764      <NA>  2021-01-25 08:38:00   2021-01-25 08:50:00             <NA>
#
# ...

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" BIGINT,
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count BIGINT,
# 	trip_distance FLOAT(53),
# 	"RatecodeID" BIGINT,
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type BIGINT,
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
len(df)
# Out:
# 1369765

# %%
df_iter = pd.read_csv(
    url,
    dtype=dtype,
    parse_dates=parse_dates,
    iterator=True,
    chunksize=100000,
)

# %%
df_iter

# %%
for df in df_iter:
    print(len(df))
# Out:
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 100000
# 69765

# %%
#for df in df_iter:
 #   df.head(n=0).to_sql(name='yellow_taxi_data', con=engine, if_exists='append')

# %%
# Out:
# Resolved 120 packages in 0.77ms
# Audited 13 packages in 0.19ms
# Audited 1 package in 6ms

# %%
# !uv pip install tqdm
# !uv add tqdm
# !uv pip install ipywidgets
# Out:
# Audited 1 package in 1ms

# %%
from tqdm.auto import tqdm

# %%
for df_chunk in tqdm(df_iter):
    df_chunk.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# 0it [00:00, ?it/s]

# %%
from tqdm.notebook import tqdm

for df_chunk in tqdm(df_iter, desc="Uploading chunks"):
    df_chunk.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# Uploading chunks: 0it [00:00, ?it/s]

# %%
# !uv pip install --python "{sys.executable}" ipywidgets
# Out:
# Audited 1 package in 4ms

# %%
# !uv pip install --python "{sys.executable}" notebook
# Out:
# Audited 1 package in 64ms

# %%
# Simple tqdm test
from tqdm.auto import tqdm
import time  # just to slow down for visibility

# Loop 10 iterations with a progress bar
for i in tqdm(range(10), desc="Testing tqdm", ncols=80):
    time.sleep(0.2)  # sleep 0.2 seconds so you can see the bar updating

print("✅ tqdm is working!")
# Out:
# Testing tqdm:   0%|                                      | 0/10 [00:00<?, ?it/s]
# ✅ tqdm is working!
